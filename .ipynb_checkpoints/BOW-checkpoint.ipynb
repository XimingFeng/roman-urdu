# %%
import pandas as pd
import sklearn

# %%
df = pd.read_csv('Roman Urdu DataSet.csv')

# %%
df.head()
# Out:
#                                              Comment Sentiment
# 0  Sai kha ya her kisi kay bus ki bat nhi hai lak...  Positive
# 1                                          sahi bt h  Positive
# 2                                        Kya bt hai,  Positive
# 3                                         Wah je wah  Positive
# 4                               Are wha kaya bat hai  Positive

# %%
df["Comment"]
# Out:
# 0        Sai kha ya her kisi kay bus ki bat nhi hai lak...
# 1                                                sahi bt h
# 2                                              Kya bt hai,
# 3                                               Wah je wah
# 4                                     Are wha kaya bat hai
#                                ...
# 20224             Hamari jese awam teli laga k mazay leti
# 20225    Kaash hum b parhay likhay hotayKabhi likhtay g...
# 20226    Bahi sayasat kufrrr ha saaaf bttttt ha qanon s...
# 20227                       aanti toh gussa e kr gai hain
# 20228    mai b sirf shadi kanry ki waja say imran khan ...
# Name: Comment, Length: 20229, dtype: object

# %%
df["Sentiment"]
# Out:
# 0        Positive
# 1        Positive
# 2        Positive
# 3        Positive
# 4        Positive
#            ...
# 20224    Negative
# 20225    Negative
# 20226    Negative
# 20227    Negative
# 20228    Positive
# Name: Sentiment, Length: 20229, dtype: object

# %%
import nltk
import string
import re

# %%
toy_set = df.head()
comment_list = []
pattern = re.compile("^[a-zA-Z]+$")
for idx, comments in df.iterrows():
    words = nltk.word_tokenize(str(comments['Comment']))
    for word in words:
        if not pattern.match(word):
            words.remove(word)
    comment_list.append(words)
            
print(len(comment_list))
# Out:
# 20229

# %%
import gensim
from gensim.models import Word2Vec

# %%
word2vec_model = Word2Vec(sentences=comment_list)
# word2vec_model = Word2Vec.load('word2vec.bin')

# %%
words = word2vec_model.wv.vocab
print(words)
# Out:
# {'shirts': <gensim.models.keyedvectors.Vocab object at 0x7f35b8398630>, 'jald': <gensim.models.keyedvectors.Vocab object at 0x7f357c1bad68>, 'totka': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b128>, 'Tayar': <gensim.models.keyedvectors.Vocab object at 0x7f357c107cf8>, 'lie': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b0f0>, 'kitni': <gensim.models.keyedvectors.Vocab object at 0x7f357c107d68>, 'haal': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b438>, 'bat': <gensim.models.keyedvectors.Vocab object at 0x7f357c141208>, 'bharti': <gensim.models.keyedvectors.Vocab object at 0x7f357c18dc18>, 'tarah': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b160>, 'waha': <gensim.models.keyedvectors.Vocab object at 0x7f357c107da0>, 'Wazir': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b198>, 'ao': <gensim.models.keyedvectors.Vocab object at 0x7f357c107dd8>, 'Hahahahaha': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b1d0>, 'Tb': <gensim.models.keyedvectors.Vocab object at 0x7f357c184400>, 'WO': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b828>, 'shahid': <gensim.models.keyedvectors.Vocab object at 0x7f357c18dc50>, 'panah': <gensim.models.keyedvectors.Vocab object at 0x7f3581d368d0>, 'duniya': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b240>, 'kheel': <gensim.models.keyedvectors.Vocab object at 0x7f357c107d30>, 'mall': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b8d0>, 'irada': <gensim.models.keyedvectors.Vocab object at 0x7f357c197748>, 'Vladimir': <gensim.models.keyedvectors.Vocab object at 0x7f357c169128>, 'bore': <gensim.models.keyedvectors.Vocab object at 0x7f357c169eb8>, 'chaa': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b278>, 'sunta': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b2b0>, 'tym': <gensim.models.keyedvectors.Vocab object at 0x7f357c1da1d0>, 'season': <gensim.models.keyedvectors.Vocab object at 0x7f357c1ba9e8>, 'peche': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b320>, 'pair': <gensim.models.keyedvectors.Vocab object at 0x7f357c1baa20>, 'admi': <gensim.models.keyedvectors.Vocab object at 0x7f357c18dc88>, 'abu': <gensim.models.keyedvectors.Vocab object at 0x7f357c107eb8>, 'aadmi': <gensim.models.keyedvectors.Vocab object at 0x7f357c107ef0>, 'coach': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b358>, 'zarorat': <gensim.models.keyedvectors.Vocab object at 0x7f357c1354e0>, 'Karli': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b390>, 'Masoom': <gensim.models.keyedvectors.Vocab object at 0x7f357c15e208>, 'Imkan': <gensim.models.keyedvectors.Vocab object at 0x7f357c1ba9b0>, 'mily': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b3c8>, 'eleven': <gensim.models.keyedvectors.Vocab object at 0x7f357c1bab38>, 'September': <gensim.models.keyedvectors.Vocab object at 0x7f357c17a1d0>, 'lete': <gensim.models.keyedvectors.Vocab object at 0x7f357c1e4e48>, 'mansab': <gensim.models.keyedvectors.Vocab object at 0x7f357c1bab00>, 'Ki': <gensim.models.keyedvectors.Vocab object at 0x7f357c14b400>, 'lon': <gensim.models.keyedvectors.Vocab object at 0x7f357c1358d0>, 'product': <gensim.models.keyedvectors.Vocab object at 0x7f357c112a20>, 'Kernay': <gensim.models.keyedvectors.Vocab object at 0x7f357c1ba908>, 'IK': <gensim.models.keyedvectors.Vocab object at 0x7f357c1ba940>, 'hou': <gensim.models.keyedvectors.Vocab object at 0x7f357c109048>, 'Urdu': <gensim.models.keyedvectors.Vocab object at 0x7f357c0b58d0>, 'blkul': <gensim.models.keyedvectors.Vocab object at 0x7f357c1baac8>, 'Tera': <gensim.models.keyedvectors.Vocab object at 0x7f357c109080>, 'ka': <gensim.models.keyedvectors.Vocab object at 0x7f357c1090b8>, 'Nhe': <gensim.models.keyedvectors.Vocab object at 0x7f357c1090f0>, 'tm': <gensim.models.keyedvectors.Vocab object at 0x7f357c1baa90>, 'NRO': <gensim.models.keyedvectors.Vocab object at 0x7f357c1bab70>, 'tadad': <gensim.models.keyedvectors.Vocab object at 0x7f357c1baba8>, 'matlab': <gensim.models.keyedvec ...

# %%
print(words['like'])
print(words['love'])
print(words['hate'])
print(words['no'])
# Out:
# Vocab(count:51, index:624, sample_int:4294967296)
# Vocab(count:60, index:528, sample_int:4294967296)
# Vocab(count:10, index:3158, sample_int:4294967296)
# Vocab(count:80, index:388, sample_int:4294967296)

# %%
word2vec_model.wv.save_word2vec_format('word2vec.bin')

# %%
X = word2vec_model[word2vec_model.wv.vocab]
# Out:
# /home/ximingfeng/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
X_reduced_2D = pca.fit_transform(X)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

import mpld3

# %%
mpld3.enable_notebook()

# %%
plt.scatter(X_reduced_2D[:, 0], X_reduced_2D[:, 1])
for i, word in enumerate(words):
    plt.annotate(word, xy=(X_reduced_2D[i, 0,], X_reduced_2D[i, 1]))
